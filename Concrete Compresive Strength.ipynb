# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats as stats

import statsmodels.api as sma
from statsmodels.stats.outliers_influence import variance_inflation_factor

import warnings
warnings.filterwarnings('ignore')

# %%
# Read The dataset

data = pd.read_excel('Concrete_Data.xls')

# %%
data.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  coarse_agg  \
# 0   540.0                 0.0      0.0  162.0               2.5      1040.0
# 1   540.0                 0.0      0.0  162.0               2.5      1055.0
# 2   332.5               142.5      0.0  228.0               0.0       932.0
# 3   332.5               142.5      0.0  228.0               0.0       932.0
# 4   198.6               132.4      0.0  192.0               0.0       978.4
#
#    fine_agg  age  comp_strength
# 0     676.0   28      79.986111
# 1     676.0   28      61.887366
# 2     594.0  270      40.269535
# 3     594.0  365      41.052780
# 4     825.5  360      44.296075

# %% [markdown]
# ### Descriptive Statistics

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cement              1030 non-null   float64
#  1   blast_furnace_slag  1030 non-null   float64
#  2   fly_ash             1030 non-null   float64
#  3   water               1030 non-null   float64
#  4   superplasticizer    1030 non-null   float64
#  5   coarse_agg          1030 non-null   float64
#  6   fine_agg            1030 non-null   float64
#  7   age                 1030 non-null   int64
#  8   comp_strength       1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %%
data.describe().T
# Out:
#                      count        mean         std         min         25%  \
# cement              1030.0  281.165631  104.507142  102.000000  192.375000
# blast_furnace_slag  1030.0   73.895485   86.279104    0.000000    0.000000
# fly_ash             1030.0   54.187136   63.996469    0.000000    0.000000
# water               1030.0  181.566359   21.355567  121.750000  164.900000
# superplasticizer    1030.0    6.203112    5.973492    0.000000    0.000000
# coarse_agg          1030.0  972.918592   77.753818  801.000000  932.000000
# fine_agg            1030.0  773.578883   80.175427  594.000000  730.950000
# age                 1030.0   45.662136   63.169912    1.000000    7.000000
# comp_strength       1030.0   35.817836   16.705679    2.331808   23.707115
#
#                            50%          75%          max
# cement              272.900000   350.000000   540.000000
# blast_furnace_slag   22.000000   142.950000   359.400000
# fly_ash               0.000000   118.270000   200.100000
# water               185.000000   192.000000   247.000000
# superplasticizer      6.350000    10.160000    32.200000
# coarse_agg          968.000000  1029.400000  1145.000000
# fine_agg            779.510000   824.000000   992.600000
# age                  28.000000    56.000000   365.000000
# comp_strength        34.442774    46.136287    82.599225

# %% [markdown]
# ### Univariate Analysis

# %%
t = 1
plt.figure(figsize=(10,12))
for i in data.columns:
    plt.subplot(5,2,t)
    sns.distplot(data[i],color='r')
    t+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
t = 1
plt.figure(figsize=(10,12))
for i in data.columns:
    if i != 'comp_strength':
        plt.subplot(4,2,t)
        sns.scatterplot(x=data[i],y=data['comp_strength'],color='salmon')
        t+=1
plt.tight_layout()
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),vmax=1,vmin=-1,cmap='RdBu',annot=True,
           mask = np.triu(data.corr()))
# Out:
# <Axes: >

# %% [markdown]
# ### Treat the defects in the dataset

# %%
# Missing Values
data.isnull().sum()
# Out:
# cement                0
# blast_furnace_slag    0
# fly_ash               0
# water                 0
# superplasticizer      0
# coarse_agg            0
# fine_agg              0
# age                   0
# comp_strength         0
# dtype: int64

# %%
# Do we have Outliers?
t = 1
plt.figure(figsize=(10,12))
for i in data.columns:
    plt.subplot(5,2,t)
    sns.boxplot(x=data[i],orient='h')
    t+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# Since we will be training a linear regression model which is highly sensitive to outliers. We will treat the extreme outliers. Just to see the effect of outliers on the model we build and compare two models one with outliers and one without outliers

# %%
# First we will the model with outliers present in the dataset
x = data.drop(columns=['comp_strength'])
y = data['comp_strength']

sma.OLS(y,sma.add_constant(x)).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          comp_strength   R-squared:                       0.615
# Model:                            OLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     204.3
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):          6.76e-206
# Time:                        10:36:12   Log-Likelihood:                -3869.0
# No. Observations:                1030   AIC:                             7756.
# Df Residuals:                    1021   BIC:                             7800.
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                -23.1638     26.588     -0.871      0.384     -75.338      29.010
# cement                 0.1198      0.008     14.110      0.000       0.103       0.136
# blast_furnace_slag     0.1038      0.010     10.245      0.000       0.084       0.124
# fly_ash                0.0879      0.013      6.988      0.000       0.063       0.113
# water                 -0.1503      0.040     -3.741      0.000      -0.229      -0.071
# superplasticizer       0.2907      0.093      3.110      0.002       0.107       0.474
# coarse_agg             0.0180      0.009      1.919      0.055      -0.000       0.036
# fine_agg               0.0202      0.011      1.883      0.060      -0.001       0.041
# age                    0.1142      0.005     21.046      0.000       0.104       0.125
# ==============================================================================
# Omnibus:                        5.379   Durbin-Watson:                   1.281
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                5.305
# Skew:                          -0.174   Prob(JB):                       0.0705
# Kurtosis:                       3.045   Cond. No.                     1.06e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Lets remove the outliers
q1 = data.quantile(0.25)
q3 = data.quantile(0.75)

iqr = q3-q1
ul = q3+1.5*iqr
ll = q1-1.5*iqr

data = data.loc[~((data>ul)|(data<ll)).any(axis=1)]

# %%
# Model without outliers present in the dataset
x = data.drop(columns=['comp_strength'])
y = data['comp_strength']

sma.OLS(y,sma.add_constant(x)).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          comp_strength   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     390.0
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):          2.92e-291
# Time:                        10:36:12   Log-Likelihood:                -3286.5
# No. Observations:                 941   AIC:                             6591.
# Df Residuals:                     932   BIC:                             6635.
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 49.9873     22.409      2.231      0.026       6.010      93.964
# cement                 0.1020      0.007     14.655      0.000       0.088       0.116
# blast_furnace_slag     0.0755      0.008      8.982      0.000       0.059       0.092
# fly_ash                0.0482      0.010      4.667      0.000       0.028       0.068
# water                 -0.2496      0.035     -7.161      0.000      -0.318      -0.181
# superplasticizer       0.2160      0.085      2.535      0.011       0.049       0.383
# coarse_agg            -0.0103      0.008     -1.311      0.190      -0.026       0.005
# fine_agg              -0.0103      0.009     -1.152      0.250      -0.028       0.007
# age                    0.3127      0.009     34.065      0.000       0.295       0.331
# ==============================================================================
# Omnibus:                        8.746   Durbin-Watson:                   1.295
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):               10.120
# Skew:                           0.147   Prob(JB):                      0.00635
# Kurtosis:                       3.414   Cond. No.                     1.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
t = 1
plt.figure(figsize=(10,12))
for i in data.columns:
    plt.subplot(5,2,t)
    sns.boxplot(x=data[i],orient='h')
    t+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
# Feature Engineering
# Instead of taking water and cement lets take cement to water ratio

x['Cem_Wat_ratio'] = x['cement']/x['water']

x.drop(columns=['cement','water'],inplace=True)

x.head()
# Out:
#    blast_furnace_slag  fly_ash  superplasticizer  coarse_agg  fine_agg  age  \
# 1                 0.0      0.0               2.5      1055.0     676.0   28
# 5               114.0      0.0               0.0       932.0     670.0   90
# 7                95.0      0.0               0.0       932.0     594.0   28
# 8               114.0      0.0               0.0       932.0     670.0   28
# 9                 0.0      0.0               0.0       932.0     594.0   28
#
#    Cem_Wat_ratio
# 1       3.333333
# 5       1.166667
# 7       1.666667
# 8       1.166667
# 9       2.083333

# %%
x['coarse_fine_ratio'] = x['coarse_agg']/x['fine_agg']

x.drop(columns=['coarse_agg','fine_agg'],inplace=True)

x.head()
# Out:
#    blast_furnace_slag  fly_ash  superplasticizer  age  Cem_Wat_ratio  \
# 1                 0.0      0.0               2.5   28       3.333333
# 5               114.0      0.0               0.0   90       1.166667
# 7                95.0      0.0               0.0   28       1.666667
# 8               114.0      0.0               0.0   28       1.166667
# 9                 0.0      0.0               0.0   28       2.083333
#
#    coarse_fine_ratio
# 1           1.560651
# 5           1.391045
# 7           1.569024
# 8           1.391045
# 9           1.569024

# %% [markdown]
# ### Building a base model

# %%
base_model = sma.OLS(y,sma.add_constant(x)).fit()
base_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          comp_strength   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     501.0
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):          7.41e-288
# Time:                        10:36:17   Log-Likelihood:                -3300.7
# No. Observations:                 941   AIC:                             6615.
# Df Residuals:                     934   BIC:                             6649.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                -16.8579      2.179     -7.735      0.000     -21.135     -12.581
# blast_furnace_slag     0.0795      0.004     19.228      0.000       0.071       0.088
# fly_ash                0.0598      0.007      8.896      0.000       0.047       0.073
# superplasticizer       0.2923      0.073      3.989      0.000       0.148       0.436
# age                    0.3122      0.009     33.621      0.000       0.294       0.330
# Cem_Wat_ratio         19.3876      0.611     31.719      0.000      18.188      20.587
# coarse_fine_ratio      0.3264      1.558      0.210      0.834      -2.731       3.384
# ==============================================================================
# Omnibus:                        7.729   Durbin-Watson:                   1.273
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                8.389
# Skew:                           0.155   Prob(JB):                       0.0151
# Kurtosis:                       3.343   Cond. No.                     1.17e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Before making any Business Interpretations lets check for the assumptions

# %%
# Assumption 1: Target Must be numeric: Met

# %%
# Assumption 2: There should be no multicoliniarity

# VIF

vif_list = []

for i in range(x.shape[1]):
    vif_list.append(variance_inflation_factor(x.values,i))
    
pd.DataFrame({'Feature Name':x.columns,'VIF':vif_list}).\
sort_values(by='VIF',ascending=False)
# Out:
#          Feature Name        VIF
# 5   coarse_fine_ratio  18.748741
# 4       Cem_Wat_ratio  13.385894
# 2    superplasticizer   5.190011
# 1             fly_ash   4.526993
# 0  blast_furnace_slag   2.973961
# 3                 age   2.246780

# %%
# In order to deal with multicolinearity we need to remove columns one by
# one and check the scores of the model

# Model without coarse fine ration : negligible drop

x_c = sma.add_constant(x)

sma.OLS(y,x_c.drop(columns=['coarse_fine_ratio'])).fit().rsquared
# Out:
# 0.7629229457193574

# %%
# Model without cement water ratio : negligible drop

sma.OLS(y,x_c.drop(columns=['Cem_Wat_ratio'])).fit().rsquared
# Out:
# 0.507570016848549

# %%
# Lets drop coarge fine ratio from the model and calculate the VIF again

x.drop(columns=['coarse_fine_ratio'],inplace=True)

vif_list = []

for i in range(x.shape[1]):
    vif_list.append(variance_inflation_factor(x.values,i))
    
pd.DataFrame({'Feature Name':x.columns,'VIF':vif_list}).\
sort_values(by='VIF',ascending=False)
# Out:
#          Feature Name       VIF
# 2    superplasticizer  3.933220
# 4       Cem_Wat_ratio  3.117410
# 1             fly_ash  2.420682
# 3                 age  2.128090
# 0  blast_furnace_slag  1.612342

# %% [markdown]
# ## Model 1

# %%
model_1=sma.OLS(y,sma.add_constant(x)).fit()
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          comp_strength   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     601.8
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):          2.94e-289
# Time:                        10:36:17   Log-Likelihood:                -3300.7
# No. Observations:                 941   AIC:                             6613.
# Df Residuals:                     935   BIC:                             6643.
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                -16.4837      1.248    -13.209      0.000     -18.933     -14.035
# blast_furnace_slag     0.0796      0.004     19.587      0.000       0.072       0.088
# fly_ash                0.0601      0.007      9.052      0.000       0.047       0.073
# superplasticizer       0.2879      0.070      4.102      0.000       0.150       0.426
# age                    0.3122      0.009     33.639      0.000       0.294       0.330
# Cem_Wat_ratio         19.4152      0.597     32.540      0.000      18.244      20.586
# ==============================================================================
# Omnibus:                        7.756   Durbin-Watson:                   1.271
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                8.407
# Skew:                           0.156   Prob(JB):                       0.0149
# Kurtosis:                       3.342   Cond. No.                         619.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.figure(figsize=(8,10))
t=1
for i in x.columns:
    plt.subplot(3,2,t)
    sns.scatterplot(x=x[i],y=model_1.resid)
    t+=1
plt.tight_layout()
plt.show()

# %%
# rainbow to check linearity
#Ho: variables are linear
#Ha: Variables are not linear
from statsmodels.stats.diagnostic import linear_rainbow
p_value=linear_rainbow(model_1)[1]

if p_value< 0.05:
    print('Reject Ho: Variables are not linear')
else:
        print('Faileed to Reject Ho: Variables are linear')
# Out:
# Faileed to Reject Ho: Variables are linear

# %%
 # Assumption 4:
    
# d= 1.271

# %% [markdown]
# since durbin watson statistic is less than 1.5<d<2.5 we can say that there is some positive autocorelation in the dataset

# %%
# Assumption 5: The residuals must be homoscedastic

sns.residplot(x=model_1.fittedvalues,y=model_1.resid,color='violet')
# Out:
# <Axes: >

# %%
# Breusch pagan test

#Ho: the variances are same: Homoscedastic
#Ha: the variances are not same: Heteroscedastic


p_value=sma.stats.diagnostic.het_breuschpagan(model_1.resid,model_1.model.exog)[1]
print('p-value',p_value)
if p_value<0.05:
    print('Reject Ho: Residuals are Heteroscedastic')
else:
        print('Failed to reject Ho: Residuals are Homoscedastic')
# Out:
# p-value 1.6514582654405928e-20
# Reject Ho: Residuals are Heteroscedastic

# %%
# Assumption 6: the residual must be normal


# qq plot

stats.probplot(model_1.resid,plot=plt);
#plt.show()

# %%
# shapiro-wilk test

#Ho: data is normal
#Ha: data is not normal

stats.shapiro(model_1.resid)
# Out:
# ShapiroResult(statistic=0.9963052868843079, pvalue=0.02541407383978367)

# %%
# The residual are approximately normal

# %% [markdown]
# ## Business interpretation

# %%
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          comp_strength   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     601.8
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):          2.94e-289
# Time:                        10:36:24   Log-Likelihood:                -3300.7
# No. Observations:                 941   AIC:                             6613.
# Df Residuals:                     935   BIC:                             6643.
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                -16.4837      1.248    -13.209      0.000     -18.933     -14.035
# blast_furnace_slag     0.0796      0.004     19.587      0.000       0.072       0.088
# fly_ash                0.0601      0.007      9.052      0.000       0.047       0.073
# superplasticizer       0.2879      0.070      4.102      0.000       0.150       0.426
# age                    0.3122      0.009     33.639      0.000       0.294       0.330
# Cem_Wat_ratio         19.4152      0.597     32.540      0.000      18.244      20.586
# ==============================================================================
# Omnibus:                        7.756   Durbin-Watson:                   1.271
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                8.407
# Skew:                           0.156   Prob(JB):                       0.0149
# Kurtosis:                       3.342   Cond. No.                         619.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# *
#
# * 1: All the features are significant
#
# * 2: The coefficient being  -16.4837 is absurd because with no composition, negative compressive strength makes no sense.
#
# * 3: one unit increase in cem/water ratio increases the strength by 19 Mpa
#
# * 4: If the concrete ages  by 1 day there is increase in strength by 0.3122 Mpa
#
# * 5: Adding a superplasticizer by 1 unit increases the strength by 0.2879 Mpa
#
# *

# %% [markdown]
# ## Predictive Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_absolute_percentage_error,mean_squared_error

from sklearn.linear_model import LinearRegression

# %%
# Re-fitted model on train dataset

# lets split the data into train and test

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,train_size=0.7,random_state=1)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (658, 5) (283, 5) (658,) (283,)

# %%
model_lr= LinearRegression()
model_lr.fit(x_train,y_train)  # training a model
# Out:
# LinearRegression()

# %%
y_pred= model_lr.predict(x_test) # getting y predicted values by giving x testing values

# %%
print('R-squared:',r2_score(y_test,y_pred))# getting r squared score by comparing y testing values and y predicted values

r2=r2_score(y_test,y_pred)
n=len(y_test)
k= x_test.shape[1]


print('Adjusted r2:',1-(((1-r2)*(n-1))/(n-k-1)))
print('MSE:',mean_squared_error(y_test,y_pred))
print('RMSE:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('MAE:',mean_absolute_error(y_test,y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test,y_pred))
# Out:
# R-squared: 0.7576581307991506
# Adjusted r2: 0.7532837288280161
# MSE: 64.39266071824974
# RMSE: 8.024503767726062
# MAE: 6.175142548891698
# MAPE: 0.24597490784901666

# %%
print('Training Data ')

y_pred=model_lr.predict(x_train)

print('R-Squared:',r2_score(y_train,y_pred))

r2 = r2_score(y_train,y_pred)
n = len(y_test)
k = x_test.shape[1]

print('Adjusted R2:',1-(((1-r2)*(n-1))/(n-k-1)))
print('MSE:',mean_squared_error(y_train,y_pred))
print('RMSE:',np.sqrt(mean_squared_error(y_train,y_pred)))
print('MAE:',mean_absolute_error(y_train,y_pred))
print('MAPE:',mean_absolute_percentage_error(y_train,y_pred))
# Out:
# Training Data
# R-Squared: 0.7638332843763261
# Adjusted R2: 0.7595703472712056
# MSE: 65.84229224938892
# RMSE: 8.114326358323833
# MAE: 6.368805904638593
# MAPE: 0.2270580506693398

# %% [markdown]
# ## ML Pipeline

# %% [markdown]
# Step 1: Data Preprocessig
# 1. Collection
# 2. Formatting
# 3. Labelling
#
# Step 2: Feature Extraction
# 1. Feature Transformation
# 2. Feature Engineering
# 3. Feature Selection
#
# Step 3: Modeling
# 1. Model Building
# 2. Model Evaluation
#
# Step 4: Optimization
# 1. Prediction Evaluation
# 2. Model Validation
# 3. Model Fine Tuning
#
# Step 5: Deployment

# %% [markdown]
# ### Deployment

# %% [markdown]
# import pickle

# %% [markdown]
# with open('lr_model.pkl','wb') as file:  # our trained model is saved as a file, we can share that trained model as file for use
#     pickle.dump(model_lr,file)

# %% [markdown]
# model_lr.feature_names_in_
